# %%
import pandas as pd
import glob
import os

# %%
# Paths to datasets with DePlot tables
data_pattern = '/Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/**/*-ctt.csv'

# %%
''' Convert data string to a DataFrame and a title '''
def string_to_dataframe_and_title(data_string, filepath):
    # Split the data into rows
    rows = data_string.strip().split("&&&")
    
    title = None
    header = None

    # Check if the first row is a title and extract it
    if "TITLE |" in rows[0]:
        potential_title = rows[0].split(" | ", 1)[1]  # Split and take second part as the potential title
        if potential_title.strip().lower() not in ['', 'title']: # Handle cases with placeholder titles
            title = potential_title  # Only set title if it's meaningful
        rows.pop(0)  # Remove the title row from processing

    # The next row should be the header
    if rows:
        header = [h.strip() for h in rows.pop(0).split("|") if h.strip()]
    else:
        raise ValueError("No header row found after the title row.")

    # Check if there are any data rows left after removing title and header
    if not rows:
        raise ValueError("No data rows found after the header row.")

    # Split remaining rows based on number of headers
    records = []
    for row in rows:
        record = [r.strip() for r in row.strip().split("|") if r.strip()]
        if len(record) != len(header):
            print(f"File: {filepath}: Row has {len(record)} columns, expected {len(header)} - row data: {record}")
            return None, title  # to keep original CSV instead
        records.append(record)

    # Create df and convert data to numeric where possible
    df = pd.DataFrame(records, columns=header).apply(pd.to_numeric, errors='ignore')

    return df, title

# %%
''' Save the title to a separate txt file '''
def save_title_to_file(title, filepath):
    if title:
        title_filepath = f"{filepath.rsplit('.', 1)[0]}-title.txt" # Add '-title' extention
        with open(title_filepath, 'w') as f:
            f.write(title)

# %%
# Pattern for matching csvs in FigureQA and PlotQA
for filepath in glob.glob(data_pattern, recursive=True):
    with open(filepath, 'r') as file:
        data_string = file.read()

    try:
        result = string_to_dataframe_and_title(data_string, filepath)
        if result is None:
            print(f"Skipping conversion for {filepath} because it removes data.")
            continue

        df, title = result

        if df is not None:
            # Save the DataFrame (overwrite original file)
            df.to_csv(filepath, index=False)
                
            # Save the title to a separate file
            save_title_to_file(title, filepath)
    except ValueError as e:
        print(f"Error processing {filepath}: {e}")
# Out:
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/test/tables/plotQA_11287-test-ctt.csv: Row has 4 columns, expected 3 - row data: ['Honduras', '196490000.0', '3920000.0', '1982']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/test/tables/plotQA_12070-test-ctt.csv: Row has 5 columns, expected 3 - row data: ['& Primary schools', '105.2458', '1982', '1982', '1982']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/test/tables/plotQA_14337-test-ctt.csv: Row has 4 columns, expected 3 - row data: ['& Small states', '64.0836845870564837185', '2009', '2012']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/test/tables/plotQA_10652-test-ctt.csv: Row has 0 columns, expected 3 - row data: []
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/test/tables/plotQA_23271-test-ctt.csv: Row has 5 columns, expected 3 - row data: ['US$', '1962', '-131860015.& US$', '1964', '119008800.0']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_29462-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Females', '43.66699298888884221', '1997', '1998']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_74200-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Trained teachers male', '67. South Africa', '67. Fland', 'Worldwimbling machinery']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_119000-train-ctt.csv: Row has 5 columns, expected 3 - row data: ['1961', 'Gambia', 'Gambia, The', '49.449', '40.599']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_128637-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Belize', '2013', '2013', '82.21397490906060606060606084']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_24065-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Tuberculosis case detection rate', '3', '100', '100']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_31380-train-ctt.csv: Row has 2 columns, expected 3 - row data: ['Exports of goods', 'Belize']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_125494-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['& Ukraine', '2005', '2005', '202.0']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_104821-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Grants', 'Bhutan', 'Bhutan', '17.98658874025122294901']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_64161-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['& 198150000.0', '10000.0', '400000.0', 'Sri Lanka']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_133917-train-ctt.csv: Row has 5 columns, expected 3 - row data: ['&& Total', 'Sweden', 'Dakota', '685807994824.1210 1.5228', '68.0']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_63009-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['& Kenya', '3610000.0', '40000.0', '2000']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_49472-train-ctt.csv: Row has 1 columns, expected 3 - row data: ['& State of South America total merchandiseraming from trade of goods and social networks and social networks and social networks and social networks and social networks and social networks and social networks and social networks and social networks and social networks and social networks and social networks and social networks and social networks and social networks and social networks and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social and social']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_59099-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Social Protection', '2.5', '2007', '2007']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_64349-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Saudi Arabia', '18595000000.0', '2010', '2012']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_75399-train-ctt.csv: Row has 132 columns, expected 3 - row data: ['Social networkware infected keywords && Social networkwareness', '10500000', '10500000', '105000000000000100010001000100010001', '100.48000000000', '100.48000000000', '100.48000000000', '100.48000000000', '100,29999', '100,29999', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', '100,29', 'Dominican Socialonia', 'Dominican Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Socialonia', 'Social network network network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', 'Social network', '"']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_34846-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['& Mobile cellular', '310066800', 'Ethiopia', 'Equatorial Guinea']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_101018-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Fossil fuel energy consumption (% of total)', '2', '3', '79.4981950489385376385329']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_9485-train-ctt.csv: Row has 5 columns, expected 3 - row data: ['Belgium', '4', '10.15610919928996858 && Belgium', '0', '10.0958339908585312']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_94356-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Kuwait', '5', '7', '681000000.0']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_108062-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Female', 'Djibouti', 'Djibouti', '7.80000019']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_46681-train-ctt.csv: Row has 127 columns, expected 3 - row data: ['& Iceland', '58.5', '68.5', '68.0', '68.0', '68.4000015', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '68.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '66.0', '56.0', '56.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '58.0', '55.9']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_124600-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Europe(all income levels)', '2003', '2003', '3.4500328892889840586991299']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_88077-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Dominica', '5', '4', '70000.0']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_90200-train-ctt.csv: Row has 0 columns, expected 3 - row data: []
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_40422-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['& 2001', '9.6', '9.6', 'Panama']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_42490-train-ctt.csv: Row has 2 columns, expected 3 - row data: ['1991', '2.40000009536743']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_112459-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['1970', 'Country', 'Low Botswana', '0.000456858546212465804580488']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_21448-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Children (0-14) living with HIV', '3', '2100', '210000']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_48051-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['& 1961', '23063.0', '21278.0', 'El Salvador']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_124137-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['& Guinea-Bissau', '2012', '2012', '0.9']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_144288-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['& Total', 'Resident workers', 'Resident workers', '6889599499500000.899.899.899.899.899.899.899.899.899.899.858.8 and Resident workers']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_123597-train-ctt.csv: Row has 0 columns, expected 3 - row data: []
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_64783-train-ctt.csv: Row has 3 columns, expected 2 - row data: ['2005', 'Sudan', '2.5']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_32523-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['& Exports', '3811616220000.0', '19682 eating from trade of Italy traveling goods', '1968228 and 1996']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_100680-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Consumption of fixed capital', '3', '0', '4.94055948785521899246299']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_82013-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Females', '3', '101.099998474121', '88.0']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_78875-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Nonresident', '5', '3', '3360']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/train/tables/plotQA_151133-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['CO2 intensity', '1993', '1993', '3.0164705194078548735862']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/val/tables/plotQA_15718-val-ctt.csv: Row has 4 columns, expected 3 - row data: ['Area of land', '324400', '324100', '1996']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/val/tables/plotQA_5893-val-ctt.csv: Row has 2 columns, expected 3 - row data: ['& Social sectors', '30. Social sectors']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/val/tables/plotQA_11868-val-ctt.csv: Row has 9 columns, expected 3 - row data: ['&& Finland', '4.371', '30.370602 emissions from residentributing social media consumption', '30.371', '30.371', '30.371', '30.371', '30.3706022181586225', '2012']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/PlotQA/val/tables/plotQA_31647-val-ctt.csv: Row has 5 columns, expected 3 - row data: ['Least1835 && Least developed countries', '2007', '2003', '2004', '10.09851835183518351835183518351835184']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_51558-train-ctt.csv: Row has 7 columns, expected 6 - row data: ['Coral', '7', '0', '2', '0', '0', '0']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_16865-train-ctt.csv: Row has 3 columns, expected 4 - row data: ['Orange Red', 'WhatsApp', 'Mom']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_97683-train-ctt.csv: Row has 3 columns, expected 2 - row data: ['Medium Turquoise', '13.625', 'pt; -']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_70355-train-ctt.csv: Row has 7 columns, expected 6 - row data: ['90.0', '82.8', '82.6', '84.9', '74.9', '72.7', '76.9']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_489-train-ctt.csv: Row has 3 columns, expected 2 - row data: ['Medium Purple', '0', '72']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_15810-train-ctt.csv: Row has 2 columns, expected 3 - row data: ['86.2', 'Dodger Blue']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_10448-train-ctt.csv: Row has 7 columns, expected 6 - row data: ['Medium Blue', '3', '3', '5', '0', '0', '0']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_19772-train-ctt.csv: Row has 3 columns, expected 2 - row data: ['Group && Total', '1.01 && Total', '1.01']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_73577-train-ctt.csv: Row has 4 columns, expected 2 - row data: ['Medium Blue', 'Male Violet', 'Steel Blue', 'Orange Red']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_80895-train-ctt.csv: Row has 5 columns, expected 4 - row data: ['12.2', '12.2', '51.3', '51.58', '54.68']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_88572-train-ctt.csv: Row has 3 columns, expected 2 - row data: ['Dec 31, 2020', '94.4 & Dec 31, 2020', '94.5']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_10137-train-ctt.csv: Row has 3 columns, expected 2 - row data: ['Crimson', '0', '72']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_3483-train-ctt.csv: Row has 156 columns, expected 2 - row data: ['& 0.53', '0.52 sak499', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '0.5', '"']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_63661-train-ctt.csv: Row has 11 columns, expected 8 - row data: ['iOS', '20.0', '21.0', '20.0', '55.0', '55.0', '54.5', '55.0', '26.8', '26.8', '21.0']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_21272-train-ctt.csv: Row has 6 columns, expected 5 - row data: ['Aqua', '0', '0', '0', '2', '2']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_78387-train-ctt.csv: Row has 3 columns, expected 2 - row data: ['6', 'New York', '90.4']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_48802-train-ctt.csv: Row has 0 columns, expected 2 - row data: []
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_98884-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['30', '65', '64', '68']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_99536-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Dant.0', '94.8', '94.9', '94.8']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_13096-train-ctt.csv: Row has 0 columns, expected 2 - row data: []
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_80654-train-ctt.csv: Row has 6 columns, expected 5 - row data: ['Composite', '78.0', '78.0', '72.7', '70.6', '65.8']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_33461-train-ctt.csv: Row has 3 columns, expected 2 - row data: ['& Gold', '4', '4']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_13202-train-ctt.csv: Row has 2 columns, expected 3 - row data: ['Medium Orchid', '32"']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_9624-train-ctt.csv: Row has 1 columns, expected 2 - row data: ['None']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_53800-train-ctt.csv: Row has 3 columns, expected 2 - row data: ['Brown', 'Medium Purple', 'Red']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_86227-train-ctt.csv: Row has 3 columns, expected 2 - row data: ['Orange', '90.0', '90.0']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_49556-train-ctt.csv: Row has 7 columns, expected 6 - row data: ['Crimson', '0', '0', '0', '3', '3', '-']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_75499-train-ctt.csv: Row has 3 columns, expected 2 - row data: ['Medium Aqua', '0', '15.0']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_61574-train-ctt.csv: Row has 3 columns, expected 2 - row data: ['Maron', '52.8', '52.9']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_81312-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['36.5', '40', '36.4', '51.4']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_96745-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['Sky Blue', '2', '16.2', '16.2']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_86573-train-ctt.csv: Row has 4 columns, expected 3 - row data: ['&& Hong Kong', '7.9', '7.9', '7. 7. 7. 7. 7. 7.9']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_49291-train-ctt.csv: Row has 1 columns, expected 2 - row data: ['34.09 && 34.09 && Web Gray']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_41738-train-ctt.csv: Row has 1 columns, expected 2 - row data: ['0']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_95767-train-ctt.csv: Row has 1 columns, expected 2 - row data: ['87.3 && 85.8']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_81266-train-ctt.csv: Row has 5 columns, expected 4 - row data: ['Sandy Brown', '0.6', '94.0', '94.5', '94.0']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_33773-train-ctt.csv: Row has 1 columns, expected 3 - row data: ['0.2']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_96926-train-ctt.csv: Row has 3 columns, expected 2 - row data: ['Light Seafood', '0', '67.08']
# File: /Users/angwang/ChartFC/seed_datasets_150_GF/3_translated_data_150_GF/FigureQA/train/tables/figureQA_14982-train-ctt.csv: Row has 6 columns, expected 5 - row data: ['Orange', '68.3', '407', '109.8', '104.7', '83.5']
# /var/folders/sx/hkqgssrx0jd_jb2_792hz_hm0000gp/T/ipykernel_16954/4250671795.py:36: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = pd.DataFrame(records, columns=header).apply(pd.to_numeric, errors='ignore')

# %%
''' Check if CSV has any data '''
def test_csv_conversion(directory_pattern):
    not_converted_properly = []

    # Loop through each file in directory
    for filepath in glob.glob(directory_pattern, recursive=True):
        # Only check converted files
        if filepath.endswith('-dp.csv'):
            try:
                df = pd.read_csv(filepath)
                # If shape is (0, 1), add to list
                if df.shape == (0, 1):
                    not_converted_properly.append(filepath)
            except Exception as e: # If error reading CSV, add to list
                not_converted_properly.append(filepath)

    return not_converted_properly

# Check for files not converted properly
csvs_not_converted_properly = test_csv_conversion(data_pattern)
csvs_not_converted_properly
# Out:
# []
